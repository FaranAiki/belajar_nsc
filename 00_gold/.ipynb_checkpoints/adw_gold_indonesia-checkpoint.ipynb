# %%
# Pisahin dari 1979-2021.csv untuk extract (i guess)?

#data: https://www.investing.com/currencies/usd-idr-historical-data
#data: https://www.kaggle.com/datasets/odins0n/monthly-gold-prices/data

import numpy as np
import pandas as pd
import sklearn
import statsmodels.api as sm
import statsmodels.formula.api as smf
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt
from prophet import Prophet

from scipy import stats

from arch import arch_model

MAX_TAHUN = 2021
MIN_TAHUN = 1988

PREDIKSI_MAX = 2021 + 2021 - 1988 + 1 + 50
INTERVAL = PREDIKSI_MAX - MAX_TAHUN
RANGE = range(MIN_TAHUN, PREDIKSI_MAX)

print("Berhasil")
# Out:
# Berhasil

# %%
ORIGINAL_GOLD_FILE = "1979-2021.csv"

EXTRACTED_INDONESIA_GOLD = "indonesia_gold.csv"

raw_d = pd.read_csv(ORIGINAL_GOLD_FILE)
indo_raw = raw_d[["Date", "Indonesia(IDR)"]].copy()

indo_raw["Date"] = pd.to_datetime(indo_raw['Date'], format='%d-%m-%Y')
indo_raw["Tahun"] = indo_raw["Date"].dt.year
indo_raw["Bulan"] = indo_raw["Date"].dt.month

indo_raw = indo_raw.drop(columns=['Date'])

cols = list(indo_raw.columns)
cols.remove("Tahun"), cols.remove("Bulan")
cols = ["Tahun", "Bulan"] + cols

indo_raw = indo_raw[cols]
indo_raw = indo_raw.rename(columns={"Indonesia(IDR)": "Harga Emas"})

# %%
# Truncate to fix how many are those shit idk
indo_raw = indo_raw[indo_raw["Tahun"] >= MIN_TAHUN].reset_index(drop=True)
print(indo_raw)
# Out:
#      Tahun  Bulan  Harga Emas
# 0     1988      1    780269.1
# 1     1988      2    708952.9
# 2     1988      3    755387.8
# 3     1988      4    748498.8
# 4     1988      5    775606.3
# ..     ...    ...         ...
# 398   2021      3  24562502.0
# 399   2021      4  25533702.8
# 400   2021      5  27131285.3
# 401   2021      6  25565673.6
# 402   2021      7  26404909.4
#
# [403 rows x 3 columns]

# %%
CONVERSION_RATE_FILE = "USD_IDR Historical Data.csv"

raw_conv = pd.read_csv(CONVERSION_RATE_FILE)
raw_conv = raw_conv.drop(columns=["Price", "High", "Low", "Vol.", "Change %"])
raw_conv["Date"] = pd.to_datetime(raw_conv["Date"], format="%m/%d/%Y")
raw_conv["Tahun"] = raw_conv["Date"].dt.year
raw_conv["Bulan"] = raw_conv["Date"].dt.month
raw_conv = raw_conv.rename(columns={"Open": "Rupiah"})

cols = ["Tahun", "Bulan", "Rupiah"]
raw_conv = raw_conv[cols].iloc[::-1].reset_index(drop=True)

raw_conv["Rupiah"] = raw_conv["Rupiah"].str.replace(",","").astype(float)

print(raw_conv)
# Out:
#      Tahun  Bulan   Rupiah
# 0     1988      1   1660.0
# 1     1988      2   1660.0
# 2     1988      3   1660.0
# 3     1988      4   1667.0
# 4     1988      5   1671.0
# ..     ...    ...      ...
# 392   2021      8  14465.0
# 393   2021      9  14265.0
# 394   2021     10  14310.0
# 395   2021     11  14185.0
# 396   2021     12  14344.0
#
# [397 rows x 3 columns]

# %%
# Gabungin semua datanya
dataset = pd.merge(indo_raw, raw_conv, on=["Tahun", "Bulan"], how="outer")

# forward fill
dataset = dataset.ffill()

print(dataset)
# Out:
#      Tahun  Bulan  Harga Emas   Rupiah
# 0     1988      1    780269.1   1660.0
# 1     1988      2    708952.9   1660.0
# 2     1988      3    755387.8   1660.0
# 3     1988      4    748498.8   1667.0
# 4     1988      5    775606.3   1671.0
# ..     ...    ...         ...      ...
# 403   2021      8  26404909.4  14465.0
# 404   2021      9  26404909.4  14265.0
# 405   2021     10  26404909.4  14310.0
# 406   2021     11  26404909.4  14185.0
# 407   2021     12  26404909.4  14344.0
#
# [408 rows x 4 columns]

# %%
# Buat model OLS

# Hanya bergantung pada waktu
model_tahun = smf.ols(formula="Q('Harga Emas') ~ Tahun", data=dataset).fit()
model_bulan = smf.ols(formula="Q('Harga Emas') ~ Tahun + C(Bulan)", data=dataset).fit()

print("Tahun vs Bulan (AIC): ", model_tahun.aic - model_bulan.aic)
print("Tahun vs Bulan (BIC): ", model_tahun.bic - model_bulan.bic)
# Maka tahun lebih bagus, kita gunakan tahun TANPA harus pakai bulan

print("Hasil berdasarkan tahun: ", model_tahun.summary())

# Model rupiah
model_rupiah = smf.ols(formula="Rupiah ~ Tahun", data=dataset).fit()

# Hanya bergantung pada konversi USD
model_konv = smf.ols(formula="Q('Harga Emas') ~ Q('Rupiah')", data=dataset).fit()

print("Hasil berdasarkan rupiah: ", model_konv.summary())

# Bergantung pada waktu dan konversi USD
model_multi = smf.ols(formula="Q('Harga Emas') ~ Rupiah + Tahun", data=dataset).fit()

print("Hasil gabungan: ", model_multi.summary())

print("Tahun vs Rupiah (AIC): ", model_tahun.aic - model_multi.aic)
print("Tahun vs Rupiah (BIC): ", model_tahun.bic - model_multi.bic)
# Karena positif, kita pilih model MULTI!

# Cek multikolinearitas
model_konv_rupiah = smf.ols(formula="Q('Harga Emas') ~ Q('Rupiah')", data=dataset).fit()
print("Model konv_rupiah: ", model_konv_rupiah.summary())

# prediksi untuk tahun ke-2022 sampai 2045
# model_tahun.predict({"Tahun": range(2022, 2045+1)})
# model_konv.predict({"Tahun": range(2022, 2045+1)})
predict_ols = model_tahun.predict({"Tahun": RANGE})

total_ols = predict_ols

print(total_ols)
# Out:
# Tahun vs Bulan (AIC):  -19.968885623118695
# Tahun vs Bulan (BIC):  -64.09282454156346
# Hasil berdasarkan tahun:                              OLS Regression Results
# ==============================================================================
# Dep. Variable:        Q('Harga Emas')   R-squared:                       0.869
# Model:                            OLS   Adj. R-squared:                  0.869
# Method:                 Least Squares   F-statistic:                     2692.
# Date:                Tue, 16 Jun 2026   Prob (F-statistic):          3.04e-181
# Time:                        18:04:53   Log-Likelihood:                -6636.0
# No. Observations:                 408   AIC:                         1.328e+04
# Df Residuals:                     406   BIC:                         1.328e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.466e+09   2.84e+07    -51.598      0.000   -1.52e+09   -1.41e+09
# Tahun       7.353e+05   1.42e+04     51.880      0.000    7.07e+05    7.63e+05
# ==============================================================================
# Omnibus:                       25.478   Durbin-Watson:                   0.040
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.836
# Skew:                           0.649   Prob(JB):                     5.48e-07
# Kurtosis:                       3.104   Cond. No.                     4.10e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.1e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Hasil berdasarkan rupiah:                              OLS Regression Results
# ==============================================================================
# Dep. Variable:        Q('Harga Emas')   R-squared:                       0.673
# Model:                            OLS   Adj. R-squared:                  0.673
# Method:                 Least Squares   F-statistic:                     837.5
# Date:                Tue, 16 Jun 2026   Prob (F-statistic):          1.00e-100
# Time:                        18:04:53   Log-Likelihood:                -6822.2
# No. Observations:                 408   AIC:                         1.365e+04
# Df Residuals:                     406   BIC:                         1.366e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept   -3.843e+06   4.64e+05     -8.277      0.000   -4.76e+06   -2.93e+06
# Q('Rupiah')  1444.2629     49.906     28.939      0.000    1346.156    1542.370
# ==============================================================================
# Omnibus:                        1.250   Durbin-Watson:                   0.042
# Prob(Omnibus):                  0.535   Jarque-Bera (JB):                1.296
# Skew:                          -0.132   Prob(JB):                        0.523
# Kurtosis:                       2.919   Cond. No.                     1.97e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.97e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Hasil gabungan:                              OLS Regression Results
# ==============================================================================
# Dep. Variable:        Q('Harga Emas')   R-squared:                       0.881
# Model:                            OLS   Adj. R-squared:                  0.881
# Method:                 Least Squares   F-statistic:                     1501.
# Date:                Tue, 16 Jun 2026   Prob (F-statistic):          5.02e-188
# Time:                        18:04:53   Log-Likelihood:                -6616.1
# No. Observations:                 408   AIC:                         1.324e+04
# Df Residuals:                     405   BIC:                         1.325e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.888e+09   7.08e+07    -26.652      0.000   -2.03e+09   -1.75e+09
# Rupiah      -512.7633     79.516     -6.449      0.000    -669.079    -356.447
# Tahun        9.48e+05   3.56e+04     26.598      0.000    8.78e+05    1.02e+06
# ==============================================================================
# Omnibus:                       41.104   Durbin-Watson:                   0.057
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               50.617
# Skew:                           0.836   Prob(JB):                     1.02e-11
# Kurtosis:                       3.425   Cond. No.                     5.06e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.06e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# Tahun vs Rupiah (AIC):  37.87767826095296
# Tahun vs Rupiah (BIC):  33.866411086550215
# Model konv_rupiah:                              OLS Regression Results
# ==============================================================================
# Dep. Variable:        Q('Harga Emas')   R-squared:                       0.673
# Model:                            OLS   Adj. R-squared:                  0.673
# Method:                 Least Squares   F-statistic:                     837.5
# Date:                Tue, 16 Jun 2026   Prob (F-statistic):          1.00e-100
# Time:                        18:04:53   Log-Likelihood:                -6822.2
# No. Observations:                 408   AIC:                         1.365e+04
# Df Residuals:                     406   BIC:                         1.366e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept   -3.843e+06   4.64e+05     -8.277      0.000   -4.76e+06   -2.93e+06
# Q('Rupiah')  1444.2629     49.906     28.939      0.000    1346.156    1542.370
# ==============================================================================
# Omnibus:                        1.250   Durbin-Watson:                   0.042
# Prob(Omnibus):                  0.535   Jarque-Bera (JB):                1.296
# Skew:                          -0.132   Prob(JB):                        0.523
# Kurtosis:                       2.919   Cond. No.                     1.97e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.97e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# 0     -4.136040e+06
# 1     -3.400693e+06
# 2     -2.665346e+06
# 3     -1.929998e+06
# 4     -1.194651e+06
#            ...
# 112    7.822284e+07
# 113    7.895819e+07
# 114    7.969353e+07
# 115    8.042888e+07
# 116    8.116423e+07
# Length: 117, dtype: float64

# %%
# Buat model Analisis Deret Waktu menggunakan ARIMA
# Yang endogen saja, P > |z| sudah bagus
arima_rupiah = ARIMA(dataset['Rupiah'], order=(1, 1, 1), trend='t').fit()

my_arima_model = ARIMA(dataset['Harga Emas'], order=(1, 1, 1), trend='t').fit()
print(my_arima_model.summary())

# Buat model Analisis Deret Waktu menggunakan ARIMAX (X = dari USD)
arima_multi = ARIMA(
    endog=dataset['Harga Emas'],
    exog=dataset['Rupiah'],
    order=(1, 1, 1),
    trend='t',
).fit()

print(arima_multi.summary())

total_arima = pd.concat([dataset['Harga Emas'][::12], arima_multi.forecast(INTERVAL, exog=arima_rupiah.forecast(INTERVAL))])
total_arima = total_arima.reset_index(drop=True)

print(total_arima)
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             Harga Emas   No. Observations:                  408
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -5951.648
# Date:                Tue, 16 Jun 2026   AIC                          11911.297
# Time:                        18:04:53   BIC                          11927.332
# Sample:                             0   HQIC                         11917.643
#                                 - 408
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1          6.296e+04   2.09e+04      3.011      0.003     2.2e+04    1.04e+05
# ar.L1          0.5056      0.101      5.000      0.000       0.307       0.704
# ma.L1         -0.6448      0.089     -7.249      0.000      -0.819      -0.470
# sigma2      2.972e+11      0.012   2.53e+13      0.000    2.97e+11    2.97e+11
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):              1795.78
# Prob(Q):                              0.89   Prob(JB):                         0.00
# Heteroskedasticity (H):              12.25   Skew:                             1.13
# Prob(H) (two-sided):                  0.00   Kurtosis:                        13.04
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 5.14e+35. Standard errors may be unstable.
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             Harga Emas   No. Observations:                  408
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -5951.387
# Date:                Tue, 16 Jun 2026   AIC                          11912.775
# Time:                        18:04:53   BIC                          11932.819
# Sample:                             0   HQIC                         11920.707
#                                 - 408
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# drift        6.25e+04   2.16e+04      2.898      0.004    2.02e+04    1.05e+05
# Rupiah        14.8882     46.187      0.322      0.747     -75.636     105.413
# ar.L1          0.4930      0.108      4.560      0.000       0.281       0.705
# ma.L1         -0.6364      0.094     -6.780      0.000      -0.820      -0.452
# sigma2      2.968e+11      0.011   2.59e+13      0.000    2.97e+11    2.97e+11
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):              1802.42
# Prob(Q):                              0.89   Prob(JB):                         0.00
# Heteroskedasticity (H):              12.49   Skew:                             1.13
# Prob(H) (two-sided):                  0.00   Kurtosis:                        13.06
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 2.99e+29. Standard errors may be unstable.
# 0      7.802691e+05
# 1      6.898906e+05
# 2      7.454005e+05
# 3      6.977633e+05
# 4      7.080949e+05
#            ...
# 113    3.147516e+07
# 114    3.153812e+07
# 115    3.160108e+07
# 116    3.166404e+07
# 117    3.172700e+07
# Length: 118, dtype: float64

# %%
plt.figure(figsize=(14, 7)) # Bikin kanvas gede biar mantap

# B. Plot Garis OLS (Warna Merah Putus-putus)
# Kita gabungin garis historis dan masa depan biar keliatan kaku-nya OLS dari ujung ke ujung
plt.plot(range(MIN_TAHUN, MIN_TAHUN + len(total_ols)), total_ols, color='red', linestyle='--', alpha=0.7)

plt.plot(range(MIN_TAHUN, MIN_TAHUN + len(total_arima)), total_arima, color='green', linewidth=2.5, label='Forecast ARIMA (Fleksibel & Nanjak)')

# %%
# Akan digunakan ARIMA, kemudian ARCH & GARCH sebagai komparasi
# Pakai my_arima_model

print(my_arima_model.resid)

arch = arch_model(my_arima_model.resid, mean='Zero', vol='Arch', p=1, q=1, rescale=False).fit(update_freq=0)
print(arch.summary())

garch = arch_model(my_arima_model.resid, mean='Zero', vol='Garch', p=1, q=1, rescale=False).fit(update_freq=0)
print(garch.summary())

# Karena Garch better, pake ini
cond_vola = garch.conditional_volatility
 
print(cond_vola)
# Out:
# 0      717309.295822
# 1      -46159.057866
# 2       21911.354342
# 3      -47426.712961
# 4      -31063.034033
#            ...
# 403    -13184.474639
# 404    -39629.199906
# 405    -56680.597746
# 406    -67675.235254
# 407    -74764.510576
# Length: 408, dtype: float64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5908.32880777774
#             Iterations: 2
#             Function evaluations: 6
#             Gradient evaluations: 2
#                         Zero Mean - ARCH Model Results
# ==============================================================================
# Dep. Variable:                   None   R-squared:                       0.000
# Mean Model:                 Zero Mean   Adj. R-squared:                  0.002
# Vol Model:                       ARCH   Log-Likelihood:               -5908.33
# Distribution:                  Normal   AIC:                           11820.7
# Method:            Maximum Likelihood   BIC:                           11828.7
#                                         No. Observations:                  408
# Date:                Tue, Jun 16 2026   Df Residuals:                      408
# Time:                        18:44:04   Df Model:                            0
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      1.3275e+11  7.005e+10      1.895  5.809e-02 [-4.549e+09,2.701e+11]
# alpha[1]       1.0000      0.492      2.032  4.213e-02    [3.557e-02,  1.964]
# =============================================================================
#
# Covariance estimator: robust
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5763.598893531083
#             Iterations: 5
#             Function evaluations: 21
#             Gradient evaluations: 5
#                        Zero Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                   None   R-squared:                       0.000
# Mean Model:                 Zero Mean   Adj. R-squared:                  0.002
# Vol Model:                      GARCH   Log-Likelihood:               -5763.60
# Distribution:                  Normal   AIC:                           11533.2
# Method:            Maximum Likelihood   BIC:                           11545.2
#                                         No. Observations:                  408
# Date:                Tue, Jun 16 2026   Df Residuals:                      408
# Time:                        18:44:04   Df Model:                            0
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      5.9003e+09  2.695e+10      0.219      0.827 [-4.692e+10,5.872e+10]
# alpha[1]       0.3673      0.158      2.325  2.008e-02    [5.764e-02,  0.677]
# beta[1]        0.6327      0.309      2.049  4.042e-02    [2.763e-02,  1.238]
# =============================================================================
#
# Covariance estimator: robust
# 0      2.094503e+05
# 1      4.718322e+05
# 2      3.841184e+05
# 3      3.153339e+05
# 4      2.639000e+05
#            ...
# 403    1.124260e+06
# 404    8.976202e+05
# 405    7.185329e+05
# 406    5.777173e+05
# 407    4.677220e+05
# Name: cond_vol, Length: 408, dtype: float64

# %%
plt.figure(figsize=(12, 6))
plt.plot(my_arima_model.resid.index + MIN_TAHUN, my_arima_model.resid, label='Residu dari ARIMA', color='gray', alpha=0.5)

plt.plot(cond_vola.index + MIN_TAHUN, 1.96 * cond_vola, 
         color='green', label='+95% Risk Bound (GARCH)', linewidth=1.5)
plt.plot(cond_vola.index + MIN_TAHUN, -1.96 * cond_vola, 
         color='red', label='-95% Risk Bound (GARCH)', linewidth=1.5)

# plt.plot(my_arima_model.resid.index[::4], total_arima, color='green', linewidth=2.5, label='Forecast ARIMA (Fleksibel & Nanjak)')


plt.title('Residu ARIMA dibandingkan GARCH dengan risiko 95%', fontsize=14)
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Akan digunakan ARIMA, kemudian ARCH & GARCH sebagai komparasi
# Pakai my_arima_model

print(arima_multi.resid)

archm = arch_model(arima_multi.resid, mean='Zero', vol='Arch', p=1, q=1, rescale=False).fit(update_freq=0)
print(archm.summary())

garchm = arch_model(arima_multi.resid, mean='Zero', vol='Garch', p=1, q=1, rescale=False).fit(update_freq=0)
print(garchm.summary())

# Karena Garch better, pake ini
cond_volam = garchm.conditional_volatility
 
print(cond_volam)
# Out:
# 0      693058.746103
# 1      -46103.575526
# 2       20878.252752
# 3      -48342.023463
# 4      -31900.933353
#            ...
# 403    -10202.671106
# 404    -35531.794810
# 405    -56435.496697
# 406    -65408.600436
# 407    -76594.705288
# Length: 408, dtype: float64
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5907.550970293137
#             Iterations: 2
#             Function evaluations: 6
#             Gradient evaluations: 2
#                         Zero Mean - ARCH Model Results
# ==============================================================================
# Dep. Variable:                   None   R-squared:                       0.000
# Mean Model:                 Zero Mean   Adj. R-squared:                  0.002
# Vol Model:                       ARCH   Log-Likelihood:               -5907.55
# Distribution:                  Normal   AIC:                           11819.1
# Method:            Maximum Likelihood   BIC:                           11827.1
#                                         No. Observations:                  408
# Date:                Tue, Jun 16 2026   Df Residuals:                      408
# Time:                        18:50:07   Df Model:                            0
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      1.3255e+11  7.080e+10      1.872  6.118e-02 [-6.214e+09,2.713e+11]
# alpha[1]       1.0000      0.494      2.025  4.287e-02    [3.208e-02,  1.968]
# =============================================================================
#
# Covariance estimator: robust
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 5762.081311838585
#             Iterations: 5
#             Function evaluations: 21
#             Gradient evaluations: 5
#                        Zero Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                   None   R-squared:                       0.000
# Mean Model:                 Zero Mean   Adj. R-squared:                  0.002
# Vol Model:                      GARCH   Log-Likelihood:               -5762.08
# Distribution:                  Normal   AIC:                           11530.2
# Method:            Maximum Likelihood   BIC:                           11542.2
#                                         No. Observations:                  408
# Date:                Tue, Jun 16 2026   Df Residuals:                      408
# Time:                        18:50:07   Df Model:                            0
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega      5.8911e+09  2.061e+10      0.286      0.775 [-3.450e+10,4.628e+10]
# alpha[1]       0.3685      0.120      3.069  2.150e-03      [  0.133,  0.604]
# beta[1]        0.6315      0.232      2.725  6.422e-03      [  0.177,  1.086]
# =============================================================================
#
# Covariance estimator: robust
# 0      2.043896e+05
# 1      4.574613e+05
# 2      3.725995e+05
# 3      3.061439e+05
# 4      2.567873e+05
#            ...
# 403    1.119723e+06
# 404    8.931406e+05
# 405    7.142195e+05
# 406    5.737617e+05
# 407    4.640704e+05
# Name: cond_vol, Length: 408, dtype: float64

# %%
plt.figure(figsize=(12, 6))
plt.plot(arima_multi.resid.index + MIN_TAHUN, arima_multi.resid, label='Residu dari ARIMAX', color='gray', alpha=0.5)

plt.plot(cond_volam.index + MIN_TAHUN, 1.96 * cond_volam, 
         color='green', label='+95% Risk Bound (GARCH)', linewidth=1.5)
plt.plot(cond_volam.index + MIN_TAHUN, -1.96 * cond_volam, 
         color='red', label='-95% Risk Bound (GARCH)', linewidth=1.5)

# plt.plot(my_arima_model.resid.index[::4], total_arima, color='green', linewidth=2.5, label='Forecast ARIMA (Fleksibel & Nanjak)')


plt.title('Residu ARIMAX dibandingkan GARCH dengan risiko 95%', fontsize=14)
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()
